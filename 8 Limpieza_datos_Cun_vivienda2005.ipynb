# %% [markdown]
# ### **1 Recolección de datos**

# %% [markdown]
# Los archivos de Personas del censo 2005

# %% [markdown]
# #### **Librerias**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### **1.1 Cargar los Datos**

# %%
#CARGA DE LOS ARCHIVOS CENSO Personas 2018 de Cundinamarca
df=pd.read_csv("/content/CG2005_AMPLIADO_1VIV_AN_25.CSV")

# %% [markdown]
# ### **2 Estructura general del DataFrame**

# %% [markdown]
# ### **2.1 Ver las primeras y últimas filas**
#   Sirve para ver una muestra de los datos y entender su estructura.

# %%
df.head()
# Out:
#    RECORD  I0A_DPTO  I0B_MPIO  I0C_CLASER  I0B1_LOCALIDAD  SEC_AGAD  \
# 0       1        25         1           1              99  20119364
# 1       1        25         1           1              99  20119364
# 2       1        25         1           1              99  20119364
# 3       1        25         1           1              99  20119364
# 4       1        25         1           1              99  20119364
#
#    I0F_EDIFIC  I0G_UCENSAL  V01B_TIP_VIV  VC01B_TOT_HOG  ...  V05B2_ALCANTARI  \
# 0           2            1             1              1  ...                1
# 1           6            1             1              1  ...                1
# 2           8            1             1              1  ...                1
# 3          13            1             1              2  ...                1
# 4          17            1             3              1  ...                1
#
#    V05B3_ACUEDUCTO  V05B4_GAS_NAT  V05B5_TELEFONO  V06A_TIPO_SERSA  \
# 0                1              2               1                1
# 1                1              2               2                1
# 2                1              2               1                1
# 3                2              2               2                1
# 4                1              2               2                1
#
#    V07A_AGUA_SERVI  V08A_NRO_BANOS  V09A_EXISTE_COCINA  FACT_EXP_CAL_V_N  \
# 0                1               1                   1          3.407150
# 1                2               0                   1          3.407150
# 2                1               1                   1          3.407150
# 3                1               1                   1          1.868841
# 4                1               2                   1          2.557760
#
#         LLAVE_VIV_N
# 0  2011936400020001
# 1  2011936400060001
# 2  2011936400080001
# 3  2011936400130001
# 4  2011936400170001
#
# [5 rows x 24 columns]

# %%
df.tail()
# Out:
#         RECORD  I0A_DPTO  I0B_MPIO  I0C_CLASER  I0B1_LOCALIDAD  SEC_AGAD  \
# 194770       1        25       899           4              99  20132285
# 194771       1        25       899           4              99  20132285
# 194772       1        25       899           4              99  20132285
# 194773       1        25       899           4              99  20132285
# 194774       1        25       899           4              99  20132285
#
#         I0F_EDIFIC  I0G_UCENSAL  V01B_TIP_VIV  VC01B_TOT_HOG  ...  \
# 194770        1502            1             3              1  ...
# 194771        1504            3             3              1  ...
# 194772        1505            1             3              1  ...
# 194773        1505            2             3              1  ...
# 194774        1509            2             3              1  ...
#
#         V05B2_ALCANTARI  V05B3_ACUEDUCTO  V05B4_GAS_NAT  V05B5_TELEFONO  \
# 194770                2                1              2               1
# 194771                1                1              2               2
# 194772                1                1              2               2
# 194773                1                1              2               2
# 194774                1                1              2               2
#
#         V06A_TIPO_SERSA  V07A_AGUA_SERVI  V08A_NRO_BANOS  V09A_EXISTE_COCINA  \
# 194770                2                1               1                   1
# 194771                1                1               1                   1
# 194772                1                1               1                   1
# 194773                1                1               2                   1
# 194774                1                1               1                   1
#
#         FACT_EXP_CAL_V_N       LLAVE_VIV_N
# 194770         10.530612  2013228515020001
# 194771         10.530612  2013228515040003
# 194772         10.530612  2013228515050001
# 194773         10.530612  2013228515050002
# 194774         10.530612  2013228515090002
#
# [5 rows x 24 columns]

# %% [markdown]
# ### **2.2 Dimensión del DataFrame**
#   Nos dice cuántas filas y columnas tiene.

# %%
df.shape
# Out:
# (194775, 24)

# %% [markdown]
# ### **2.3 Nombres de las Columnas e Información Resumen**
#   Ayuda a conocer cómo están nombradas las columnas.

# %%
# COLUMNAS QUE CONFORMAN EL ARCHIVO
df.columns
# Out:
# Index(['RECORD', 'I0A_DPTO', 'I0B_MPIO', 'I0C_CLASER', 'I0B1_LOCALIDAD',
#        'SEC_AGAD', 'I0F_EDIFIC', 'I0G_UCENSAL', 'V01B_TIP_VIV',
#        'VC01B_TOT_HOG', 'V02A_MAT_PARED', 'V03A_MAT_PISOS', 'V04A_ELI_BASURA',
#        'V05B1_ELECTRICA', 'V05B2_ALCANTARI', 'V05B3_ACUEDUCTO',
#        'V05B4_GAS_NAT', 'V05B5_TELEFONO', 'V06A_TIPO_SERSA', 'V07A_AGUA_SERVI',
#        'V08A_NRO_BANOS', 'V09A_EXISTE_COCINA', 'FACT_EXP_CAL_V_N',
#        'LLAVE_VIV_N'],
#       dtype='object')

# %% [markdown]
# Información General sobre los Datos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194775 entries, 0 to 194774
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   RECORD              194775 non-null  int64
#  1   I0A_DPTO            194775 non-null  int64
#  2   I0B_MPIO            194775 non-null  int64
#  3   I0C_CLASER          194775 non-null  int64
#  4   I0B1_LOCALIDAD      194775 non-null  int64
#  5   SEC_AGAD            194775 non-null  int64
#  6   I0F_EDIFIC          194775 non-null  int64
#  7   I0G_UCENSAL         194775 non-null  int64
#  8   V01B_TIP_VIV        194775 non-null  int64
#  9   VC01B_TOT_HOG       194775 non-null  int64
#  10  V02A_MAT_PARED      194775 non-null  int64
#  11  V03A_MAT_PISOS      194775 non-null  int64
#  12  V04A_ELI_BASURA     194775 non-null  int64
#  13  V05B1_ELECTRICA     194775 non-null  int64
#  14  V05B2_ALCANTARI     194775 non-null  int64
#  15  V05B3_ACUEDUCTO     194775 non-null  int64
#  16  V05B4_GAS_NAT       194775 non-null  int64
#  17  V05B5_TELEFONO      194775 non-null  int64
#  18  V06A_TIPO_SERSA     194775 non-null  int64
#  19  V07A_AGUA_SERVI     194775 non-null  int64
#  20  V08A_NRO_BANOS      194775 non-null  int64
#  21  V09A_EXISTE_COCINA  194775 non-null  int64
#  22  FACT_EXP_CAL_V_N    194775 non-null  float64
#  23  LLAVE_VIV_N         194775 non-null  int64
# dtypes: float64(1), int64(23)
# memory usage: 35.7 MB

# %%
df.describe(include="all").T
# Out:
#                        count          mean           std           min  \
# RECORD              194775.0  1.000000e+00  0.000000e+00  1.000000e+00
# I0A_DPTO            194775.0  2.500000e+01  0.000000e+00  2.500000e+01
# I0B_MPIO            194775.0  4.903529e+02  2.680918e+02  1.000000e+00
# I0C_CLASER          194775.0  2.876457e+00  1.451995e+00  1.000000e+00
# I0B1_LOCALIDAD      194775.0  9.759296e+01  1.153193e+01  1.000000e+00
# SEC_AGAD            194775.0  2.012577e+07  3.815683e+03  2.011936e+07
# I0F_EDIFIC          194775.0  4.140717e+02  5.983306e+02  1.000000e+00
# I0G_UCENSAL         194775.0  1.079199e+00  8.105546e-01  1.000000e+00
# V01B_TIP_VIV        194775.0  1.276036e+00  7.440672e-01  1.000000e+00
# VC01B_TOT_HOG       194775.0  1.129072e+00  5.096597e-01  1.000000e+00
# V02A_MAT_PARED      194775.0  1.509537e+00  1.013752e+00  1.000000e+00
# V03A_MAT_PISOS      194775.0  2.963337e+00  9.908066e-01  1.000000e+00
# V04A_ELI_BASURA     194775.0  2.178159e+00  1.248669e+00  1.000000e+00
# V05B1_ELECTRICA     194775.0  1.068043e+00  2.518197e-01  1.000000e+00
# V05B2_ALCANTARI     194775.0  1.554075e+00  4.970685e-01  1.000000e+00
# V05B3_ACUEDUCTO     194775.0  1.289688e+00  4.536187e-01  1.000000e+00
# V05B4_GAS_NAT       194775.0  1.939474e+00  4.561741e-01  1.000000e+00
# V05B5_TELEFONO      194775.0  1.844708e+00  8.123503e-01  1.000000e+00
# V06A_TIPO_SERSA     194775.0  1.883804e+00  9.935054e-01  1.000000e+00
# V07A_AGUA_SERVI     194775.0  1.545476e+00  1.309148e+00  1.000000e+00
# V08A_NRO_BANOS      194775.0  3.386092e+00  1.525066e+01  0.000000e+00
# V09A_EXISTE_COCINA  194775.0  1.263894e+00  1.250931e+00  1.000000e+00
# FACT_EXP_CAL_V_N    194775.0  2.768879e+00  6.133995e+00  8.076707e-01
# LLAVE_VIV_N         194775.0  2.012577e+15  3.815678e+11  2.011936e+15
#
#                              25%           50%           75%           max
# RECORD              1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# I0A_DPTO            2.500000e+01  2.500000e+01  2.500000e+01  2.500000e+01
# I0B_MPIO            2.790000e+02  4.730000e+02  7.690000e+02  8.990000e+02
# I0C_CLASER          1.000000e+00  4.000000e+00  4.000000e+00  4.000000e+00
# I0B1_LOCALIDAD      9.900000e+01  9.900000e+01  9.900000e+01  9.900000e+01
# SEC_AGAD            2.012224e+07  2.012583e+07  2.012979e+07  2.013228e+07
# I0F_EDIFIC          1.600000e+01  1.300000e+02  6.190000e+02  5.145000e+03
# I0G_UCENSAL         1.000000e+00  1.000000e+00  1.000000e+00  1.030000e+02
# V01B_TIP_VIV        1.000000e+00  1.000000e+00  1.000000e+00  5.000000e+00
# VC01B_TOT_HOG       1.000000e+00  1.000000e+00  1.000000e+00  2.000000e+01
# V02A_MAT_PARED      1.000000e+00  1.000000e+00  2.000000e+00  9.000000e+00
# V03A_MAT_PISOS      2.000000e+00  3.000000e+00  3.000000e+00  9.000000e+00
# V04A_ELI_BASURA     1.000000e+00  2.000000e+00  3.000000e+00  9.000000e+00
# V05B1_ELECTRICA     1.000000e+00  1.000000e+00  1.000000e+00  2.000000e+00
# V05B2_ALCANTARI     1.000000e+00  2.000000e+00  2.000000e+00  2.000000e+00
# V05B3_ACUEDUCTO     1.000000e+00  1.000000e+00  2.000000e+00  2.000000e+00
# V05B4_GAS_NAT       2.000000e+00  2.000000e+00  2.000000e+00  9.000000e+00
# V05B5_TELEFONO      2.000000e+00  2.000000e+00  2.000000e+00  9.000000e+00
# V06A_TIPO_SERSA     1.000000e+00  2.000000e+00  2.000000e+00  9.000000e+00
# V07A_AGUA_SERVI     1.000000e+00  1.000000e+00  2.000000e+00  9.000000e+00
# V08A_NRO_BANOS      1.000000e+00  1.000000e+00  1.000000e+00  9.900000e+01
# V09A_EXISTE_COCINA  1.000000e+00  1.000000e+00  1.000000e+00  9.000000e+00
# FACT_EXP_CAL_V_N    1.000000e+00  1.000000e+00  1.775602e+00  1.322222e+02
# LLAVE_VIV_N         2.012224e+15  2.012583e+15  2.012979e+15  2.013229e+15

# %% [markdown]
# ### **3 Data Cleaning**

# %% [markdown]
# #### **Librerias**

# %% [markdown]
# #### **Cargar los Datos**

# %%
df=pd.read_csv("/content/CG2005_AMPLIADO_1VIV_AN_25.CSV")

# %% [markdown]
# #### **3.1 Identificación de columnas y eliminación**

# %% [markdown]
# Se realiza una comparación entre los censos 2005 y 2018, se buscan las columnas que tengan en común, adicional se buscan las columnas que nos ayudaran a nuestro estudio.

# %% [markdown]
# Columnas identificadas para su eliminación:
#
# RECORD
# I0B1_LOCALIDAD
# SEC_AGAD
# I0F_EDIFIC
# I0G_UCENSAL
# VC01B_TOT_HOG
# V04A_ELI_BASURA
# V05B2_ALCANTARI
# V05B3_ACUEDUCTO
# V05B4_GAS_NAT
# V05B5_TELEFONO
# V06A_TIPO_SERSA
# V07A_AGUA_SERVI
# V08A_NRO_BANOS
# V09A_EXISTE_COCINA
# FACT_EXP_CAL_V_N
# I0C_CLASER
# V03A_MAT_PISOS

# %%
# Vivienda 2005

df = df.drop(columns=['RECORD'])
df = df.drop(columns=['I0B1_LOCALIDAD'])
df = df.drop(columns=['SEC_AGAD'])
df = df.drop(columns=['I0F_EDIFIC'])
df = df.drop(columns=['I0G_UCENSAL'])
df = df.drop(columns=['VC01B_TOT_HOG'])
df = df.drop(columns=['V04A_ELI_BASURA'])
df = df.drop(columns=['V05B2_ALCANTARI'])
df = df.drop(columns=['V05B3_ACUEDUCTO'])
df = df.drop(columns=['V05B4_GAS_NAT'])
df = df.drop(columns=['V05B5_TELEFONO'])
df = df.drop(columns=['V06A_TIPO_SERSA'])
df = df.drop(columns=['V07A_AGUA_SERVI'])
df = df.drop(columns=['V08A_NRO_BANOS'])
df = df.drop(columns=['V09A_EXISTE_COCINA'])
df = df.drop(columns=['FACT_EXP_CAL_V_N'])
df = df.drop(columns=['I0C_CLASER'])
df = df.drop(columns=['V03A_MAT_PISOS'])

# %%
df.head()
# Out:
#    I0A_DPTO  I0B_MPIO  V01B_TIP_VIV  V02A_MAT_PARED  V05B1_ELECTRICA  \
# 0        25         1             1               1                1
# 1        25         1             1               1                1
# 2        25         1             1               2                1
# 3        25         1             1               1                1
# 4        25         1             3               1                1
#
#         LLAVE_VIV_N
# 0  2011936400020001
# 1  2011936400060001
# 2  2011936400080001
# 3  2011936400130001
# 4  2011936400170001

# %% [markdown]
# #### **3.2 Categorizar**

# %%
import missingno as msno
msno.matrix(df, figsize=(8, 5), fontsize=10, color=(0.5, 0.5, 1))
# Out:
# <Axes: >

# %%
# Definir las condiciones  TIPO VIVIENDA
conditions = [
    (df['V01B_TIP_VIV'] == 1),
    (df['V01B_TIP_VIV'] == 2),
    (df['V01B_TIP_VIV'] == 3),
    (df['V01B_TIP_VIV'] == 4),
    (df['V01B_TIP_VIV'] == 5)
]

# Definir los valores que tomará la nueva columna
values = ['1 Casa', '2 Casa indigena', '3 Apartamento', '4 Tipo cuarto',  '5 Otro tipo de vivienda' ]

# Crear la nueva columna usando numpy.select()
df['TIPO_VIVIENDA_CATEGORIA'] = np.select(conditions, values, default='Desconocido')

# %%
# Definir las condiciones  TIPO PAREDES
conditions = [
    (df['V02A_MAT_PARED'] == 1),
    (df['V02A_MAT_PARED'] == 2),
    (df['V02A_MAT_PARED'] == 3),
    (df['V02A_MAT_PARED'] == 4),
    (df['V02A_MAT_PARED'] == 5),
    (df['V02A_MAT_PARED'] == 6),
    (df['V02A_MAT_PARED'] == 7),
    (df['V02A_MAT_PARED'] == 9) | (df['V02A_MAT_PARED'] == 0) |(df['V02A_MAT_PARED'].isna())
]

# Definir los valores que tomará la nueva columna
values = ['1 Bloque, ladrillo, piedra, madera pulida', '2 Tapia pisada, adobe, bahareque', '3 Madera burda, tabla, tablón', '4 Material prefabricado',  '5 Guadua, caña, esterilla, otros vegetales',
          '6 Zinc, tela, cartón, latas, desechos, plásticos', '7 Sin paredes', '9 No Informa']

# Crear la nueva columna usando numpy.select()
df['TIPO_PAREDES_CATEGORIA'] = np.select(conditions, values, default='9 No Informa')

# %%
# Definir las condiciones  TIPO ENERGIA
conditions = [
    (df['V05B1_ELECTRICA'] == 1),
    (df['V05B1_ELECTRICA'] == 2)
]

# Definir los valores que tomará la nueva columna
values = ['1 SI', '2 NO']

# Crear la nueva columna usando numpy.select()
df['TIPO_ENERGIA_CATEGORIA'] = np.select(conditions, values, default='9 No Informa')

# %% [markdown]
# #### **3.3 Identificación y Manejo Valores Nulos**

# %%
nan_counts = df.isna().sum()
nan_counts.sort_values(ascending = False)
# Out:
# I0A_DPTO                   0
# I0B_MPIO                   0
# V01B_TIP_VIV               0
# V02A_MAT_PARED             0
# V05B1_ELECTRICA            0
# LLAVE_VIV_N                0
# TIPO_VIVIENDA_CATEGORIA    0
# TIPO_PAREDES_CATEGORIA     0
# TIPO_ENERGIA_CATEGORIA     0
# dtype: int64

# %%
import missingno as msno
msno.matrix(df, figsize=(8, 5), fontsize=10, color=(0.5, 0.5, 1))
# Out:
# <Axes: >

# %%
import missingno as msno
msno.bar(df, figsize=(8, 4), fontsize=10, color=(0.5, 0.5, 1))

s = pd.Series([np.nan, 1, 2, np.nan, 3])
s = s.fillna(method='ffill')
# Out:
# <ipython-input-17-575db8b678e2>:5: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   s = s.fillna(method='ffill')

# %% [markdown]
# #### **3.4 Agregar columna AÑO**

# %%
df['AÑO'] = 2005

# %% [markdown]
# #### **3.5 Convertir columnas a categoria**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194775 entries, 0 to 194774
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   I0A_DPTO                 194775 non-null  int64
#  1   I0B_MPIO                 194775 non-null  int64
#  2   V01B_TIP_VIV             194775 non-null  int64
#  3   V02A_MAT_PARED           194775 non-null  int64
#  4   V05B1_ELECTRICA          194775 non-null  int64
#  5   LLAVE_VIV_N              194775 non-null  int64
#  6   TIPO_VIVIENDA_CATEGORIA  194775 non-null  object
#  7   TIPO_PAREDES_CATEGORIA   194775 non-null  object
#  8   TIPO_ENERGIA_CATEGORIA   194775 non-null  object
#  9   AÑO                      194775 non-null  int64
# dtypes: int64(7), object(3)
# memory usage: 14.9+ MB

# %%
# LA MAYORIA DE LAS VARIABLES SON CATEGORICAS SE REALIZA SU TRANSFORMACION:
df["TIPO_VIVIENDA_CATEGORIA"] = df["TIPO_VIVIENDA_CATEGORIA"].astype("category")
df["TIPO_PAREDES_CATEGORIA"] = df["TIPO_PAREDES_CATEGORIA"].astype("category")
df["TIPO_ENERGIA_CATEGORIA"] = df["TIPO_ENERGIA_CATEGORIA"].astype("category")
df["LLAVE_VIV_N"] = df["LLAVE_VIV_N"].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194775 entries, 0 to 194774
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   I0A_DPTO                 194775 non-null  int64
#  1   I0B_MPIO                 194775 non-null  int64
#  2   V01B_TIP_VIV             194775 non-null  int64
#  3   V02A_MAT_PARED           194775 non-null  int64
#  4   V05B1_ELECTRICA          194775 non-null  int64
#  5   LLAVE_VIV_N              194775 non-null  category
#  6   TIPO_VIVIENDA_CATEGORIA  194775 non-null  category
#  7   TIPO_PAREDES_CATEGORIA   194775 non-null  category
#  8   TIPO_ENERGIA_CATEGORIA   194775 non-null  category
#  9   AÑO                      194775 non-null  int64
# dtypes: category(4), int64(6)
# memory usage: 15.7 MB

# %% [markdown]
# ### **3.6. Agregar Departamento y municipios**

# %%
# SE REALIZA UNA COPIA CON LOS CAMBIOS REALIZADOS HASTA EL MOMENTO
df.to_csv('CensoVivienda2005_Cun.csv')

# %%
# Cargar datos si es necesario
df = pd.read_csv("/CensoVivienda2005_Cun.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-23b782c9e7cb> in <cell line: 0>()
#       1 # Cargar datos si es necesario
# ----> 2 df = pd.read_csv("/content/CensoPersonas2018_CUN.csv", index=False)
#
# TypeError: read_csv() got an unexpected keyword argument 'index'

# %%
# ARCHIVO CON LA INFORMACION DE LOS DEPARTAMENTOS
# Información obtenida de:

# https://www.datos.gov.co/Mapas-Nacionales/DEPARTAMENTOS/25e3-npng/about_data
# https://geoportal.dane.gov.co/descargas/divipola/DIVIPOLA_Municipios.xlsx

df_departamentos = pd.read_csv("/content/Departamentos.csv", delimiter=';')
df_departamentos.head()
# Out:
#    PK_DEPARTAMENTO DEPARTAMENTO_NOMBRE  FK_REGION
# 0                5           Antioquia          2
# 1                8           Atlántico          6
# 2               11         Bogotá D.C.          4
# 3               13             Bolívar          6
# 4               15              Boyacá          4

# %%
# ARCHIVO CON LA INFORMACION DE LOS MUNICIPIOS
df_municipios = pd.read_csv("/content/MunicipiosCundinamarca1.csv", delimiter=',')
df_municipios.head()
# Out:
#    PK_MUNICIPIO  PK_MUNICIPIO_SIN_DEPARTAMENTO NOMBRE_MUNICIPIO  LONGITUD  \
# 0         25001                              1     AGUA DE DIOS -74669224
# 1         25019                             19            ALBAN -74438264
# 2         25035                             35         ANAPOIMA -74528672
# 3         25040                             40         ANOLAIMA  -7446384
# 4         25053                             53         ARBELAEZ -74414904
#
#    LACTITUD  FK_DEPARTAMENTO
# 0   4375309               25
# 1   4878022               25
# 2   4562737               25
# 3     47617               25
# 4   4272534               25

# %%
# USO DEL JOIN PARA UNIR LA INFORMACION DEPARTAMENTO
df_merged = df.merge(df_departamentos,  left_on='I0A_DPTO', right_on='PK_DEPARTAMENTO', how='left')

# %%
df_merged.head()
# Out:
#    I0A_DPTO  I0B_MPIO  V01B_TIP_VIV  V02A_MAT_PARED  V05B1_ELECTRICA  \
# 0        25         1             1               1                1
# 1        25         1             1               1                1
# 2        25         1             1               2                1
# 3        25         1             1               1                1
# 4        25         1             3               1                1
#
#         LLAVE_VIV_N TIPO_VIVIENDA_CATEGORIA  \
# 0  2011936400020001                  1 Casa
# 1  2011936400060001                  1 Casa
# 2  2011936400080001                  1 Casa
# 3  2011936400130001                  1 Casa
# 4  2011936400170001           3 Apartamento
#
#                       TIPO_PAREDES_CATEGORIA TIPO_ENERGIA_CATEGORIA   AÑO  \
# 0  1 Bloque, ladrillo, piedra, madera pulida                   1 SI  2005
# 1  1 Bloque, ladrillo, piedra, madera pulida                   1 SI  2005
# 2           2 Tapia pisada, adobe, bahareque                   1 SI  2005
# 3  1 Bloque, ladrillo, piedra, madera pulida                   1 SI  2005
# 4  1 Bloque, ladrillo, piedra, madera pulida                   1 SI  2005
#
#    PK_DEPARTAMENTO DEPARTAMENTO_NOMBRE  FK_REGION
# 0               25        Cundinamarca          4
# 1               25        Cundinamarca          4
# 2               25        Cundinamarca          4
# 3               25        Cundinamarca          4
# 4               25        Cundinamarca          4

# %%
# USO DEL JOIN PARA UNIR LA INFORMACION MUNICIPIOS
df_merged = df_merged.merge(df_municipios,  left_on='I0B_MPIO', right_on='PK_MUNICIPIO_SIN_DEPARTAMENTO', how='left')

# %%
df_merged.head()
# Out:
#    I0A_DPTO  I0B_MPIO  V01B_TIP_VIV  V02A_MAT_PARED  V05B1_ELECTRICA  \
# 0        25         1             1               1                1
# 1        25         1             1               1                1
# 2        25         1             1               2                1
# 3        25         1             1               1                1
# 4        25         1             3               1                1
#
#         LLAVE_VIV_N TIPO_VIVIENDA_CATEGORIA  \
# 0  2011936400020001                  1 Casa
# 1  2011936400060001                  1 Casa
# 2  2011936400080001                  1 Casa
# 3  2011936400130001                  1 Casa
# 4  2011936400170001           3 Apartamento
#
#                       TIPO_PAREDES_CATEGORIA TIPO_ENERGIA_CATEGORIA   AÑO  \
# 0  1 Bloque, ladrillo, piedra, madera pulida                   1 SI  2005
# 1  1 Bloque, ladrillo, piedra, madera pulida                   1 SI  2005
# 2           2 Tapia pisada, adobe, bahareque                   1 SI  2005
# 3  1 Bloque, ladrillo, piedra, madera pulida                   1 SI  2005
# 4  1 Bloque, ladrillo, piedra, madera pulida                   1 SI  2005
#
#    PK_DEPARTAMENTO DEPARTAMENTO_NOMBRE  FK_REGION  PK_MUNICIPIO  \
# 0               25        Cundinamarca          4         25001
# 1               25        Cundinamarca          4         25001
# 2               25        Cundinamarca          4         25001
# 3               25        Cundinamarca          4         25001
# 4               25        Cundinamarca          4         25001
#
#    PK_MUNICIPIO_SIN_DEPARTAMENTO NOMBRE_MUNICIPIO  LONGITUD  LACTITUD  \
# 0                              1     AGUA DE DIOS -74669224   4375309
# 1                              1     AGUA DE DIOS -74669224   4375309
# 2                              1     AGUA DE DIOS -74669224   4375309
# 3                              1     AGUA DE DIOS -74669224   4375309
# 4                              1     AGUA DE DIOS -74669224   4375309
#
#    FK_DEPARTAMENTO
# 0               25
# 1               25
# 2               25
# 3               25
# 4               25

# %%
df_final= df_merged.copy()

# %%
df_final.columns
# Out:
# Index(['I0A_DPTO', 'I0B_MPIO', 'V01B_TIP_VIV', 'V02A_MAT_PARED',
#        'V05B1_ELECTRICA', 'LLAVE_VIV_N', 'TIPO_VIVIENDA_CATEGORIA',
#        'TIPO_PAREDES_CATEGORIA', 'TIPO_ENERGIA_CATEGORIA', 'AÑO',
#        'PK_DEPARTAMENTO', 'DEPARTAMENTO_NOMBRE', 'FK_REGION', 'PK_MUNICIPIO',
#        'PK_MUNICIPIO_SIN_DEPARTAMENTO', 'NOMBRE_MUNICIPIO', 'LONGITUD',
#        'LACTITUD', 'FK_DEPARTAMENTO'],
#       dtype='object')

# %%
df_final = df_final.drop(columns=['I0A_DPTO'])
df_final = df_final.drop(columns=['I0B_MPIO'])
df_final = df_final.drop(columns=['V01B_TIP_VIV'])
df_final = df_final.drop(columns=['V02A_MAT_PARED'])
df_final = df_final.drop(columns=['V05B1_ELECTRICA'])
df_final = df_final.drop(columns=['PK_DEPARTAMENTO'])
df_final = df_final.drop(columns=['FK_REGION'])
df_final = df_final.drop(columns=['PK_MUNICIPIO'])
df_final = df_final.drop(columns=['PK_MUNICIPIO_SIN_DEPARTAMENTO'])
df_final = df_final.drop(columns=['LONGITUD'])
df_final = df_final.drop(columns=['LACTITUD'])
df_final = df_final.drop(columns=['FK_DEPARTAMENTO'])

# %%
df_final.columns
# Out:
# Index(['LLAVE_VIV_N', 'TIPO_VIVIENDA_CATEGORIA', 'TIPO_PAREDES_CATEGORIA',
#        'TIPO_ENERGIA_CATEGORIA', 'AÑO', 'DEPARTAMENTO_NOMBRE',
#        'NOMBRE_MUNICIPIO'],
#       dtype='object')

# %%
df_final.isnull().sum()
# Out:
# LLAVE_VIV_N                0
# TIPO_VIVIENDA_CATEGORIA    0
# TIPO_PAREDES_CATEGORIA     0
# TIPO_ENERGIA_CATEGORIA     0
# AÑO                        0
# DEPARTAMENTO_NOMBRE        0
# NOMBRE_MUNICIPIO           0
# dtype: int64

# %% [markdown]
# ### **4. Análisis de distribución y estadístico**

# %% [markdown]
# #### **4.1 Distribución de los Datos**

# %%
for i in df_final.columns:
  print(df_final[i].describe())
  print('\n')
# Out:
# count               194775
# unique              194775
# top       2013228515090002
# freq                     1
# Name: LLAVE_VIV_N, dtype: int64
#
#
# count     194775
# unique         5
# top       1 Casa
# freq      170142
# Name: TIPO_VIVIENDA_CATEGORIA, dtype: object
#
#
# count                                        194775
# unique                                            8
# top       1 Bloque, ladrillo, piedra, madera pulida
# freq                                         140256
# Name: TIPO_PAREDES_CATEGORIA, dtype: object
#
#
# count     194775
# unique         2
# top         1 SI
# freq      181522
# Name: TIPO_ENERGIA_CATEGORIA, dtype: object
#
#
# count    194775.0
# mean       2005.0
# std           0.0
# min        2005.0
# 25%        2005.0
# 50%        2005.0
# 75%        2005.0
# max        2005.0
# Name: AÑO, dtype: float64
#
#
# count           194775
# unique               1
# top       Cundinamarca
# freq            194775
# Name: DEPARTAMENTO_NOMBRE, dtype: object
#
#
# count        194775
# unique          116
# top       LA CALERA
# freq           4790
# Name: NOMBRE_MUNICIPIO, dtype: object

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194775 entries, 0 to 194774
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   LLAVE_VIV_N              194775 non-null  category
#  1   TIPO_VIVIENDA_CATEGORIA  194775 non-null  category
#  2   TIPO_PAREDES_CATEGORIA   194775 non-null  category
#  3   TIPO_ENERGIA_CATEGORIA   194775 non-null  category
#  4   AÑO                      194775 non-null  int64
#  5   DEPARTAMENTO_NOMBRE      194775 non-null  object
#  6   NOMBRE_MUNICIPIO         194775 non-null  object
# dtypes: category(4), int64(1), object(2)
# memory usage: 11.3+ MB

# %% [markdown]
# ### **5 EXPORTAR**

# %%
# Se crea una copia del dataframe organizado
df_final.to_csv('CensoVivienda2005_CategoriaCun.csv', index=False)
