# %% [markdown]
# ### **1 Recolección de datos**

# %% [markdown]
# Los archivos de Personas del censo 2018

# %% [markdown]
# #### **Librerias**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### **1.1 Cargar los Datos**

# %%
#CARGA DE LOS ARCHIVOS CENSO Personas 2018 de Cundinamarca
df=pd.read_csv("/content/CNPV2018_5PER_A2_25.CSV")

# %% [markdown]
# ### **2 Estructura general del DataFrame**

# %% [markdown]
# ### **2.1 Ver las primeras y últimas filas**
#   Sirve para ver una muestra de los datos y entender su estructura.

# %%
df.head()
# Out:
#    TIPO_REG  U_DPTO  U_MPIO  UA_CLASE  COD_ENCUESTAS  U_VIVIENDA  P_NROHOG  \
# 0         5      25       1         1         348955           1       1.0
# 1         5      25       1         1         348955           1       1.0
# 2         5      25       1         1         348955           1       1.0
# 3         5      25       1         1         348978           1       1.0
# 4         5      25       1         1         348978           1       1.0
#
#    P_NRO_PER  P_SEXO  P_EDADR  ...  PA1_THSV  PA2_HSVH  PA3_HSVM  PA_HFC  \
# 0          1       2       16  ...       8.0       3.0       5.0     1.0
# 1          2       1       17  ...       NaN       NaN       NaN     NaN
# 2          3       2       10  ...       2.0       2.0       0.0     1.0
# 3          1       1        3  ...       NaN       NaN       NaN     NaN
# 4          2       2        6  ...       1.0       0.0       1.0     1.0
#
#    PA1_THFC  PA2_HFCH  PA3_HFCM  PA_UHNV  PA1_MES_UHNV  PA2_ANO_UHNV
# 0       0.0       0.0       0.0      1.0          11.0        1975.0
# 1       NaN       NaN       NaN      NaN           NaN           NaN
# 2       0.0       0.0       0.0      1.0          12.0        1993.0
# 3       NaN       NaN       NaN      NaN           NaN           NaN
# 4       0.0       0.0       0.0      1.0           1.0        2010.0
#
# [5 rows x 48 columns]

# %%
df.tail()
# Out:
#          TIPO_REG  U_DPTO  U_MPIO  UA_CLASE  COD_ENCUESTAS  U_VIVIENDA  \
# 2792872         5      25     899         3      902341000           1
# 2792873         5      25     899         3      902341176           1
# 2792874         5      25     899         3      902341176           1
# 2792875         5      25     899         3      902341176           1
# 2792876         5      25     899         3      902341176           1
#
#          P_NROHOG  P_NRO_PER  P_SEXO  P_EDADR  ...  PA1_THSV  PA2_HSVH  \
# 2792872       1.0          4       1       16  ...       NaN       NaN
# 2792873       1.0          1       1       10  ...       NaN       NaN
# 2792874       1.0          2       2       14  ...       NaN       NaN
# 2792875       1.0          3       1        2  ...       NaN       NaN
# 2792876       1.0          4       1        2  ...       NaN       NaN
#
#          PA3_HSVM  PA_HFC  PA1_THFC  PA2_HFCH  PA3_HFCM  PA_UHNV  \
# 2792872       NaN     NaN       NaN       NaN       NaN      NaN
# 2792873       NaN     NaN       NaN       NaN       NaN      NaN
# 2792874       NaN     NaN       NaN       NaN       NaN      NaN
# 2792875       NaN     NaN       NaN       NaN       NaN      NaN
# 2792876       NaN     NaN       NaN       NaN       NaN      NaN
#
#          PA1_MES_UHNV  PA2_ANO_UHNV
# 2792872           NaN           NaN
# 2792873           NaN           NaN
# 2792874           NaN           NaN
# 2792875           NaN           NaN
# 2792876           NaN           NaN
#
# [5 rows x 48 columns]

# %% [markdown]
# ### **2.2 Dimensión del DataFrame**
#   Nos dice cuántas filas y columnas tiene.

# %%
df.shape
# Out:
# (2792877, 48)

# %% [markdown]
# ### **2.3 Nombres de las Columnas e Información Resumen**
#   Ayuda a conocer cómo están nombradas las columnas.

# %%
# COLUMNAS QUE CONFORMAN EL ARCHIVO
df.columns

#[U_DPTO], [U_MPIO], [COD_ENCUESTAS], [P_SEXO], [P_EDADR], [PA_VIVIA_1ANO], [P_ENFERMO],
#				[P_ALFABETA], [PA_ASISTENCIA], [P_NIVEL_ANOSR], [P_TRABAJO], [P_EST_CIVIL]
# Out:
# Index(['TIPO_REG', 'U_DPTO', 'U_MPIO', 'UA_CLASE', 'COD_ENCUESTAS',
#        'U_VIVIENDA', 'P_NROHOG', 'P_NRO_PER', 'P_SEXO', 'P_EDADR',
#        'P_PARENTESCOR', 'PA1_GRP_ETNIC', 'PA11_COD_ETNIA', 'PA12_CLAN',
#        'PA21_COD_VITSA', 'PA22_COD_KUMPA', 'PA_HABLA_LENG', 'PA1_ENTIENDE',
#        'PB_OTRAS_LENG', 'PB1_QOTRAS_LENG', 'PA_LUG_NAC', 'PA_VIVIA_5ANOS',
#        'PA_VIVIA_1ANO', 'P_ENFERMO', 'P_QUEHIZO_PPAL', 'PA_LO_ATENDIERON',
#        'PA1_CALIDAD_SERV', 'CONDICION_FISICA', 'P_ALFABETA', 'PA_ASISTENCIA',
#        'P_NIVEL_ANOSR', 'P_TRABAJO', 'P_EST_CIVIL', 'PA_HNV', 'PA1_THNV',
#        'PA2_HNVH', 'PA3_HNVM', 'PA_HNVS', 'PA1_THSV', 'PA2_HSVH', 'PA3_HSVM',
#        'PA_HFC', 'PA1_THFC', 'PA2_HFCH', 'PA3_HFCM', 'PA_UHNV', 'PA1_MES_UHNV',
#        'PA2_ANO_UHNV'],
#       dtype='object')

# %% [markdown]
# Información General sobre los Datos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2792877 entries, 0 to 2792876
# Data columns (total 48 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   TIPO_REG          int64
#  1   U_DPTO            int64
#  2   U_MPIO            int64
#  3   UA_CLASE          int64
#  4   COD_ENCUESTAS     int64
#  5   U_VIVIENDA        int64
#  6   P_NROHOG          float64
#  7   P_NRO_PER         int64
#  8   P_SEXO            int64
#  9   P_EDADR           int64
#  10  P_PARENTESCOR     float64
#  11  PA1_GRP_ETNIC     int64
#  12  PA11_COD_ETNIA    float64
#  13  PA12_CLAN         float64
#  14  PA21_COD_VITSA    float64
#  15  PA22_COD_KUMPA    float64
#  16  PA_HABLA_LENG     float64
#  17  PA1_ENTIENDE      float64
#  18  PB_OTRAS_LENG     float64
#  19  PB1_QOTRAS_LENG   float64
#  20  PA_LUG_NAC        int64
#  21  PA_VIVIA_5ANOS    float64
#  22  PA_VIVIA_1ANO     float64
#  23  P_ENFERMO         float64
#  24  P_QUEHIZO_PPAL    float64
#  25  PA_LO_ATENDIERON  float64
#  26  PA1_CALIDAD_SERV  float64
#  27  CONDICION_FISICA  float64
#  28  P_ALFABETA        float64
#  29  PA_ASISTENCIA     float64
#  30  P_NIVEL_ANOSR     float64
#  31  P_TRABAJO         float64
#  32  P_EST_CIVIL       float64
#  33  PA_HNV            float64
#  34  PA1_THNV          float64
#  35  PA2_HNVH          float64
#  36  PA3_HNVM          float64
#  37  PA_HNVS           float64
#  38  PA1_THSV          float64
#  39  PA2_HSVH          float64
#  40  PA3_HSVM          float64
#  41  PA_HFC            float64
#  42  PA1_THFC          float64
#  43  PA2_HFCH          float64
#  44  PA3_HFCM          float64
#  45  PA_UHNV           float64
#  46  PA1_MES_UHNV      float64
#  47  PA2_ANO_UHNV      float64
# dtypes: float64(37), int64(11)
# memory usage: 1022.8 MB

# %%
df.describe(include="all").T
# Out:
#                       count          mean           std      min        25%  \
# TIPO_REG          2792877.0  5.000000e+00  0.000000e+00      5.0        5.0
# U_DPTO            2792877.0  2.500000e+01  0.000000e+00     25.0       25.0
# U_MPIO            2792877.0  5.168877e+02  2.592598e+02      1.0      286.0
# UA_CLASE          2792877.0  1.478889e+00  8.184131e-01      1.0        1.0
# COD_ENCUESTAS     2792877.0  6.526222e+07  2.130305e+08  17475.0  4801925.0
# U_VIVIENDA        2792877.0  7.953616e+00  2.954135e+01      1.0        1.0
# P_NROHOG          2768797.0  1.053121e+00  2.954383e-01      1.0        1.0
# P_NRO_PER         2792877.0  5.204260e+00  6.153728e+01      1.0        1.0
# P_SEXO            2792877.0  1.505937e+00  4.999648e-01      1.0        1.0
# P_EDADR           2792877.0  7.315930e+00  4.246253e+00      1.0        4.0
# P_PARENTESCOR     2768797.0  2.252245e+00  1.066705e+00      1.0        1.0
# PA1_GRP_ETNIC     2792877.0  6.013528e+00  4.511052e-01      1.0        6.0
# PA11_COD_ETNIA       9949.0  4.688477e+02  1.784444e+02     25.0      470.0
# PA12_CLAN             139.0  9.900000e+01  0.000000e+00     99.0       99.0
# PA21_COD_VITSA         98.0  6.387755e+00  3.582986e+00      1.0        1.0
# PA22_COD_KUMPA         98.0  2.537755e+01  4.105955e+01      1.0        1.0
# PA_HABLA_LENG       10197.0  1.850446e+00  7.153072e-01      1.0        2.0
# PA1_ENTIENDE         8112.0  1.886958e+00  4.197886e-01      1.0        2.0
# PB_OTRAS_LENG       10197.0  2.032166e+00  7.664407e-01      1.0        2.0
# PB1_QOTRAS_LENG       463.0  6.937365e+00  2.204007e+01      1.0        1.0
# PA_LUG_NAC        2792877.0  1.780868e+00  9.079271e-01      1.0        1.0
# PA_VIVIA_5ANOS    2768797.0  2.251631e+00  1.002601e+00      1.0        2.0
# PA_VIVIA_1ANO     2768797.0  2.121597e+00  7.449319e-01      1.0        2.0
# P_ENFERMO         2768797.0  1.948955e+00  7.394001e-01      1.0        2.0
# P_QUEHIZO_PPAL     313786.0  2.057737e+00  2.311458e+00      0.0        1.0
# PA_LO_ATENDIERON   239971.0  1.027491e+00  1.817580e-01      1.0        1.0
# PA1_CALIDAD_SERV   233563.0  2.206347e+00  6.469039e-01      1.0        2.0
# CONDICION_FISICA  2768797.0  1.924787e+00  2.637350e-01      1.0        2.0
# P_ALFABETA        2608788.0  1.146187e+00  9.321424e-01      1.0        1.0
# PA_ASISTENCIA     2584956.0  1.800936e+00  8.884452e-01      1.0        1.0
# P_NIVEL_ANOSR     2608788.0  5.602080e+00  1.196069e+01      1.0        2.0
# P_TRABAJO         2379207.0  3.526589e+00  2.763095e+00      0.0        1.0
# P_EST_CIVIL       2402599.0  4.148346e+00  2.712175e+00      1.0        1.0
# PA_HNV            1216928.0  1.478697e+00  1.178104e+00      1.0        1.0
# PA1_THNV           807554.0  2.869796e+00  3.854111e+00      1.0        1.0
# PA2_HNVH           807554.0  1.513945e+00  3.453963e+00      0.0        1.0
# PA3_HNVM           807554.0  1.458175e+00  3.559959e+00      0.0        1.0
# PA_HNVS            807554.0  1.020727e+00  2.232450e-01      1.0        1.0
# PA1_THSV           793798.0  3.517530e+00  9.240908e+00      0.0        1.0
# PA2_HSVH           793798.0  2.191268e+00  9.116214e+00      0.0        1.0
# PA3_HSVM           793798.0  2.162211e+00  9.176176e+00      0.0        1.0
# PA_HFC             807554.0  1.587480e+00  6.337457e-01      1.0        1.0
# PA1_THFC           349211.0  3.481448e-01  4.229737e+00      0.0        0.0
# PA2_HFCH           349211.0  2.672424e-01  4.273459e+00      0.0        0.0
# PA3_HFCM           349211.0  2.707246e-01  4.277038e+00      0.0        0.0
# PA_UHNV            807554.0  2.862939e+00  3.381270e+00      1.0        1.0
# PA1_MES_UHNV       619501.0  6.585342e+00  3.991704e+00      1.0        4.0
# PA2_ANO_UHNV       619501.0  2.018357e+03  3.685848e+02   1933.0     1993.0
#
#                          50%         75%          max
# TIPO_REG                 5.0         5.0          5.0
# U_DPTO                  25.0        25.0         25.0
# U_MPIO                 473.0       754.0        899.0
# UA_CLASE                 1.0         2.0          3.0
# COD_ENCUESTAS     10510968.0  15565941.0  950003419.0
# U_VIVIENDA               1.0         3.0        770.0
# P_NROHOG                 1.0         1.0         14.0
# P_NRO_PER                2.0         3.0       2983.0
# P_SEXO                   2.0         2.0          2.0
# P_EDADR                  7.0        10.0         21.0
# P_PARENTESCOR            2.0         3.0          5.0
# PA1_GRP_ETNIC            6.0         6.0          9.0
# PA11_COD_ETNIA         470.0       470.0        999.0
# PA12_CLAN               99.0        99.0         99.0
# PA21_COD_VITSA           9.0         9.0          9.0
# PA22_COD_KUMPA           2.0        11.0         99.0
# PA_HABLA_LENG            2.0         2.0          9.0
# PA1_ENTIENDE             2.0         2.0          9.0
# PB_OTRAS_LENG            2.0         2.0          9.0
# PB1_QOTRAS_LENG          2.0         2.0         99.0
# PA_LUG_NAC               2.0         2.0          9.0
# PA_VIVIA_5ANOS           2.0         2.0          9.0
# PA_VIVIA_1ANO            2.0         2.0          9.0
# P_ENFERMO                2.0         2.0          9.0
# P_QUEHIZO_PPAL           1.0         1.0          9.0
# PA_LO_ATENDIERON         1.0         1.0          9.0
# PA1_CALIDAD_SERV         2.0         2.0          4.0
# CONDICION_FISICA         2.0         2.0          2.0
# P_ALFABETA               1.0         1.0          9.0
# PA_ASISTENCIA            2.0         2.0          9.0
# P_NIVEL_ANOSR            4.0         7.0         99.0
# P_TRABAJO                2.0         6.0          9.0
# P_EST_CIVIL              4.0         7.0          9.0
# PA_HNV                   1.0         2.0          9.0
# PA1_THNV                 2.0         3.0         99.0
# PA2_HNVH                 1.0         2.0         99.0
# PA3_HNVM                 1.0         2.0         99.0
# PA_HNVS                  1.0         1.0          9.0
# PA1_THSV                 2.0         3.0         99.0
# PA2_HSVH                 1.0         2.0         99.0
# PA3_HSVM                 1.0         2.0         99.0
# PA_HFC                   2.0         2.0          9.0
# PA1_THFC                 0.0         0.0         99.0
# PA2_HFCH                 0.0         0.0         99.0
# PA3_HFCM                 0.0         0.0         99.0
# PA_UHNV                  1.0         1.0          9.0
# PA1_MES_UHNV             7.0        10.0         99.0
# PA2_ANO_UHNV          2004.0      2012.0       9999.0

# %% [markdown]
# ### **3 Data Cleaning**

# %% [markdown]
# #### **Librerias**

# %% [markdown]
# #### **Cargar los Datos**

# %%
df=pd.read_csv("/content/CNPV2018_5PER_A2_25.CSV")

# %% [markdown]
# #### **3.1 Identificación de columnas y eliminación**

# %% [markdown]
# Se realiza una comparación entre los censos 2005 y 2018, se buscan las columnas que tengan en común, adicional se buscan las columnas que nos ayudaran a nuestro estudio.

# %% [markdown]
# Columnas identificadas para su eliminación:
#
# TIPO_REG
# UA_CLASE
# U_VIVIENDA
# P_NROHOG
# P_NRO_PER
# P_PARENTESCOR
# PA1_GRP_ETNIC
# PA11_COD_ETNIA
# PA12_CLAN
# PA21_COD_VITSA
# PA22_COD_KUMPA
# PA_HABLA_LENG
# PA1_ENTIENDE
# PB_OTRAS_LENG
# PB1_QOTRAS_LENG
# PA_LUG_NAC
# PA_VIVIA_5ANOS
# P_QUEHIZO_PPAL
# PA_LO_ATENDIERON
# PA1_CALIDAD_SERV
# CONDICION_FISICA
# PA_HNV
# PA1_THNV
# PA2_HNVH
# PA3_HNVM
# PA_HNVS
# PA1_THSV
# PA2_HSVH
# PA3_HSVM
# PA_HFC
# PA1_THFC
# PA2_HFCH
# PA3_HFCM
# PA_UHNV
# PA1_MES_UHNV
# PA2_ANO_UHNV
# PA_ASISTENCIA
# P_ENFERMO
# P_TRABAJO
# P_EST_CIVIL

# %%
# PERSONAS 2018
df = df.drop(columns=['TIPO_REG'])
df = df.drop(columns=['UA_CLASE'])
df = df.drop(columns=['U_VIVIENDA'])
df = df.drop(columns=['P_NROHOG'])
df = df.drop(columns=['P_NRO_PER'])
df = df.drop(columns=['P_PARENTESCOR'])
df = df.drop(columns=['PA1_GRP_ETNIC'])
df = df.drop(columns=['PA11_COD_ETNIA'])
df = df.drop(columns=['PA12_CLAN'])

df = df.drop(columns=['PA21_COD_VITSA'])
df = df.drop(columns=['PA_VIVIA_1ANO'])
df = df.drop(columns=['PA22_COD_KUMPA'])
df = df.drop(columns=['PA_HABLA_LENG'])
df = df.drop(columns=['PA1_ENTIENDE'])
df = df.drop(columns=['PB1_QOTRAS_LENG'])
df = df.drop(columns=['PA_LUG_NAC'])

df = df.drop(columns=['PA_VIVIA_5ANOS'])
df = df.drop(columns=['P_QUEHIZO_PPAL'])
df = df.drop(columns=['PA_LO_ATENDIERON'])
df = df.drop(columns=['PA1_CALIDAD_SERV'])
df = df.drop(columns=['CONDICION_FISICA'])
df = df.drop(columns=['PA_HNV'])
df = df.drop(columns=['PA1_THNV'])
df = df.drop(columns=['PA2_HNVH'])

df = df.drop(columns=['PA3_HNVM'])
df = df.drop(columns=['PA_HNVS'])
df = df.drop(columns=['PA1_THSV'])
df = df.drop(columns=['PA2_HSVH'])
df = df.drop(columns=['PA3_HSVM'])
df = df.drop(columns=['PA1_THFC'])
df = df.drop(columns=['PA2_HFCH'])
df = df.drop(columns=['PA3_HFCM'])
df = df.drop(columns=['PA_UHNV'])
df = df.drop(columns=['PA1_MES_UHNV'])

df = df.drop(columns=['PA2_ANO_UHNV'])
df = df.drop(columns=['PB_OTRAS_LENG'])
df = df.drop(columns=['PA_HFC'])
df = df.drop(columns=['PA_ASISTENCIA'])
df = df.drop(columns=['P_ENFERMO'])
df = df.drop(columns=['P_TRABAJO'])
df = df.drop(columns=['P_EST_CIVIL'])

# %%
df.head()
# Out:
#    U_DPTO  U_MPIO  COD_ENCUESTAS  P_SEXO  P_EDADR  P_ALFABETA  P_NIVEL_ANOSR
# 0      25       1         348955       2       16         1.0            2.0
# 1      25       1         348955       1       17         1.0            2.0
# 2      25       1         348955       2       10         1.0            2.0
# 3      25       1         348978       1        3         1.0            3.0
# 4      25       1         348978       2        6         1.0            8.0

# %% [markdown]
# #### **3.2 Categorizar**

# %%
import missingno as msno
msno.matrix(df, figsize=(8, 5), fontsize=10, color=(0.5, 0.5, 1))
# Out:
# <Axes: >

# %%
# Definir las condiciones  sexo
conditions = [
    (df['P_SEXO'] == 1),
    (df['P_SEXO'] == 2)
]

# Definir los valores que tomará la nueva columna
values = ['1 Hombre', '2 Mujer']

# Crear la nueva columna usando numpy.select()
df['SEXO_CATEGORIA'] = np.select(conditions, values, default='Desconocido')

# %%
# Definir las condiciones  edad
conditions = [
    (df['P_EDADR'] == 1),
    (df['P_EDADR'] == 2),
    (df['P_EDADR'] == 3),
    (df['P_EDADR'] == 4),
    (df['P_EDADR'] == 5),
    (df['P_EDADR'] == 6),
    (df['P_EDADR'] == 7),
    (df['P_EDADR'] == 8),
    (df['P_EDADR'] == 9),
    (df['P_EDADR'] == 10),
    (df['P_EDADR'] == 11),
    (df['P_EDADR'] == 12),
    (df['P_EDADR'] == 13),
    (df['P_EDADR'] == 14),
    (df['P_EDADR'] == 15),
    (df['P_EDADR'] == 16),
    (df['P_EDADR'] == 17),
    (df['P_EDADR'] == 18),
    (df['P_EDADR'] == 19),
    (df['P_EDADR'] == 20),
    (df['P_EDADR'] == 21)
]

# Definir los valores que tomará la nueva columna
values = ['1 de 00 A 04 Años', '2 de 05 A 09 Años', '3 de 10 A 14 Años', '4 de 15 A 19 Años', '5 de 20 A 24 Años', '6 de 25 A 29 Años', '7 de 30 A 34 Años', '8 de 35 A 39 Años',
          '9 de 40 A 44 Años', '10 de 45 A 49 Años', '11 de 50 A 54 Años', '12 de 55 A 59 Años', '13 de 60 A 64 Años', '14 de 65 A 69 Años', '15 de 70 A 74 Años', '16 de 75 A 79 Años',
          '17 de 80 A 84 Años', '18 de 85 A 89 Años', '19 de 90 A 94 Años', '20 de 95 A 99 Años', '21 de 100 y más Años' ]

# Crear la nueva columna usando numpy.select()
df['EDAD_RANGO_CATEGORIA'] = np.select(conditions, values, default='Desconocido')

# %%
# Definir las condiciones  alfabeta
conditions = [
    (df['P_ALFABETA'] == 1),
    (df['P_ALFABETA'] == 2),
    (df['P_ALFABETA'] == 9) | (df['P_ALFABETA'].isna())
]

# Definir los valores que tomará la nueva columna
values = ['1 SI', '2 NO', '9 No Informa']

# Crear la nueva columna usando numpy.select()
df['ALFABETA_CATEGORIA'] = np.select(conditions, values, default='9 No Informa')

# %%
# Definir las condiciones  escolaridad
conditions = [
    (df['P_NIVEL_ANOSR'] == 1),
    (df['P_NIVEL_ANOSR'] == 2),
    (df['P_NIVEL_ANOSR'] == 3),
    (df['P_NIVEL_ANOSR'] == 4),
    (df['P_NIVEL_ANOSR'] == 5),
    (df['P_NIVEL_ANOSR'] == 6),
    (df['P_NIVEL_ANOSR'] == 7),
    (df['P_NIVEL_ANOSR'] == 8),
    (df['P_NIVEL_ANOSR'] == 9),
    (df['P_NIVEL_ANOSR'] == 10) | (df['P_NIVEL_ANOSR'] == 99) | (df['P_NIVEL_ANOSR'].isna())
]

# Definir los valores que tomará la nueva columna
values = ['1 Preescolar', '2 Básica primaria', '3 Básica secundaria', '4 Media academica o clasica', '5 Media tecnica',
          '6 Normalista', '7 Técnica profesional o Tecnológica', '8 Universitario', '9 Especialización, maestría, doctorado',
          '99 No Informa']

# Crear la nueva columna usando numpy.select()
df['EDUCACION_NIVEL_EDUCATIVO_CATEGORIA'] = np.select(conditions, values, default='99 No Informa')

# %% [markdown]
# #### **3.3 Identificación y Manejo Valores Nulos**

# %%
nan_counts = df.isna().sum()
nan_counts.sort_values(ascending = False)
# Out:
# P_NIVEL_ANOSR                          184089
# P_ALFABETA                             184089
# U_DPTO                                      0
# COD_ENCUESTAS                               0
# U_MPIO                                      0
# P_EDADR                                     0
# P_SEXO                                      0
# SEXO_CATEGORIA                              0
# EDAD_RANGO_CATEGORIA                        0
# ALFABETA_CATEGORIA                          0
# EDUCACION_NIVEL_EDUCATIVO_CATEGORIA         0
# dtype: int64

# %%
import missingno as msno
msno.matrix(df, figsize=(8, 5), fontsize=10, color=(0.5, 0.5, 1))
# Out:
# <Axes: >

# %%
import missingno as msno
msno.bar(df, figsize=(8, 4), fontsize=10, color=(0.5, 0.5, 1))

s = pd.Series([np.nan, 1, 2, np.nan, 3])
s = s.fillna(method='ffill')
# Out:
# <ipython-input-29-575db8b678e2>:5: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   s = s.fillna(method='ffill')

# %% [markdown]
# #### **3.4 Agregar columna AÑO**

# %%
df['AÑO'] = 2018

# %% [markdown]
# #### **3.5 Convertir columnas a categoria**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2792877 entries, 0 to 2792876
# Data columns (total 12 columns):
#  #   Column                               Dtype
# ---  ------                               -----
#  0   U_DPTO                               int64
#  1   U_MPIO                               int64
#  2   COD_ENCUESTAS                        int64
#  3   P_SEXO                               int64
#  4   P_EDADR                              int64
#  5   P_ALFABETA                           float64
#  6   P_NIVEL_ANOSR                        float64
#  7   SEXO_CATEGORIA                       object
#  8   EDAD_RANGO_CATEGORIA                 object
#  9   ALFABETA_CATEGORIA                   object
#  10  EDUCACION_NIVEL_EDUCATIVO_CATEGORIA  object
#  11  AÑO                                  int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 255.7+ MB

# %%
# LA MAYORIA DE LAS VARIABLES SON CATEGORICAS SE REALIZA SU TRANSFORMACION:
df["SEXO_CATEGORIA"] = df["SEXO_CATEGORIA"].astype("category")
df["EDAD_RANGO_CATEGORIA"] = df["EDAD_RANGO_CATEGORIA"].astype("category")
df["ALFABETA_CATEGORIA"] = df["ALFABETA_CATEGORIA"].astype("category")
df["EDUCACION_NIVEL_EDUCATIVO_CATEGORIA"] = df["EDUCACION_NIVEL_EDUCATIVO_CATEGORIA"].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2792877 entries, 0 to 2792876
# Data columns (total 12 columns):
#  #   Column                               Dtype
# ---  ------                               -----
#  0   U_DPTO                               int64
#  1   U_MPIO                               int64
#  2   COD_ENCUESTAS                        int64
#  3   P_SEXO                               int64
#  4   P_EDADR                              int64
#  5   P_ALFABETA                           float64
#  6   P_NIVEL_ANOSR                        float64
#  7   SEXO_CATEGORIA                       category
#  8   EDAD_RANGO_CATEGORIA                 category
#  9   ALFABETA_CATEGORIA                   category
#  10  EDUCACION_NIVEL_EDUCATIVO_CATEGORIA  category
#  11  AÑO                                  int64
# dtypes: category(4), float64(2), int64(6)
# memory usage: 181.1 MB

# %% [markdown]
# ### **3.6. Agregar Departamento y municipios**

# %%
# SE REALIZA UNA COPIA CON LOS CAMBIOS REALIZADOS HASTA EL MOMENTO
df.to_csv('CensoPersonas2018_CUN.csv')

# %%
# Cargar datos si es necesario
df = pd.read_csv("/content/CensoPersonas2018_CUN.csv", index=False)

# %%
# ARCHIVO CON LA INFORMACION DE LOS DEPARTAMENTOS
# Información obtenida de:

# https://www.datos.gov.co/Mapas-Nacionales/DEPARTAMENTOS/25e3-npng/about_data
# https://geoportal.dane.gov.co/descargas/divipola/DIVIPOLA_Municipios.xlsx

df_departamentos = pd.read_csv("/content/Departamentos.csv", delimiter=';')
df_departamentos.head()
# Out:
#    PK_DEPARTAMENTO DEPARTAMENTO_NOMBRE  FK_REGION
# 0                5           Antioquia          2
# 1                8           Atlántico          6
# 2               11         Bogotá D.C.          4
# 3               13             Bolívar          6
# 4               15              Boyacá          4

# %%
# ARCHIVO CON LA INFORMACION DE LOS MUNICIPIOS
df_municipios = pd.read_csv("/content/MunicipiosCundinamarca1.csv", delimiter=',')
df_municipios.head()
# Out:
#    PK_MUNICIPIO  PK_MUNICIPIO_SIN_DEPARTAMENTO NOMBRE_MUNICIPIO  LONGITUD  \
# 0         25001                              1     AGUA DE DIOS -74669224
# 1         25019                             19            ALBAN -74438264
# 2         25035                             35         ANAPOIMA -74528672
# 3         25040                             40         ANOLAIMA  -7446384
# 4         25053                             53         ARBELAEZ -74414904
#
#    LACTITUD  FK_DEPARTAMENTO
# 0   4375309               25
# 1   4878022               25
# 2   4562737               25
# 3     47617               25
# 4   4272534               25

# %%
# USO DEL JOIN PARA UNIR LA INFORMACION DEPARTAMENTO
df_merged = df.merge(df_departamentos,  left_on='U_DPTO', right_on='PK_DEPARTAMENTO', how='left')

# %%
df_merged.head()
# Out:
#    U_DPTO  U_MPIO  COD_ENCUESTAS  P_SEXO  P_EDADR  P_ALFABETA  P_NIVEL_ANOSR  \
# 0      25       1         348955       2       16         1.0            2.0
# 1      25       1         348955       1       17         1.0            2.0
# 2      25       1         348955       2       10         1.0            2.0
# 3      25       1         348978       1        3         1.0            3.0
# 4      25       1         348978       2        6         1.0            8.0
#
#   SEXO_CATEGORIA EDAD_RANGO_CATEGORIA ALFABETA_CATEGORIA  \
# 0        2 Mujer   16 de 75 A 79 Años               1 SI
# 1       1 Hombre   17 de 80 A 84 Años               1 SI
# 2        2 Mujer   10 de 45 A 49 Años               1 SI
# 3       1 Hombre    3 de 10 A 14 Años               1 SI
# 4        2 Mujer    6 de 25 A 29 Años               1 SI
#
#   EDUCACION_NIVEL_EDUCATIVO_CATEGORIA   AÑO  PK_DEPARTAMENTO  \
# 0                   2 Básica primaria  2018               25
# 1                   2 Básica primaria  2018               25
# 2                   2 Básica primaria  2018               25
# 3                 3 Básica secundaria  2018               25
# 4                     8 Universitario  2018               25
#
#   DEPARTAMENTO_NOMBRE  FK_REGION
# 0        Cundinamarca          4
# 1        Cundinamarca          4
# 2        Cundinamarca          4
# 3        Cundinamarca          4
# 4        Cundinamarca          4

# %%
# USO DEL JOIN PARA UNIR LA INFORMACION MUNICIPIOS
df_merged = df_merged.merge(df_municipios,  left_on='U_MPIO', right_on='PK_MUNICIPIO_SIN_DEPARTAMENTO', how='left')

# %%
df_merged.head()
# Out:
#    U_DPTO  U_MPIO  COD_ENCUESTAS  P_SEXO  P_EDADR  P_ALFABETA  P_NIVEL_ANOSR  \
# 0      25       1         348955       2       16         1.0            2.0
# 1      25       1         348955       1       17         1.0            2.0
# 2      25       1         348955       2       10         1.0            2.0
# 3      25       1         348978       1        3         1.0            3.0
# 4      25       1         348978       2        6         1.0            8.0
#
#   SEXO_CATEGORIA EDAD_RANGO_CATEGORIA ALFABETA_CATEGORIA  ...   AÑO  \
# 0        2 Mujer   16 de 75 A 79 Años               1 SI  ...  2018
# 1       1 Hombre   17 de 80 A 84 Años               1 SI  ...  2018
# 2        2 Mujer   10 de 45 A 49 Años               1 SI  ...  2018
# 3       1 Hombre    3 de 10 A 14 Años               1 SI  ...  2018
# 4        2 Mujer    6 de 25 A 29 Años               1 SI  ...  2018
#
#    PK_DEPARTAMENTO  DEPARTAMENTO_NOMBRE FK_REGION  PK_MUNICIPIO  \
# 0               25         Cundinamarca         4         25001
# 1               25         Cundinamarca         4         25001
# 2               25         Cundinamarca         4         25001
# 3               25         Cundinamarca         4         25001
# 4               25         Cundinamarca         4         25001
#
#    PK_MUNICIPIO_SIN_DEPARTAMENTO  NOMBRE_MUNICIPIO  LONGITUD  LACTITUD  \
# 0                              1      AGUA DE DIOS -74669224   4375309
# 1                              1      AGUA DE DIOS -74669224   4375309
# 2                              1      AGUA DE DIOS -74669224   4375309
# 3                              1      AGUA DE DIOS -74669224   4375309
# 4                              1      AGUA DE DIOS -74669224   4375309
#
#    FK_DEPARTAMENTO
# 0               25
# 1               25
# 2               25
# 3               25
# 4               25
#
# [5 rows x 21 columns]

# %%
df_final= df_merged.copy()

# %%
df_final.columns
# Out:
# Index(['U_DPTO', 'U_MPIO', 'COD_ENCUESTAS', 'P_SEXO', 'P_EDADR', 'P_ALFABETA',
#        'P_NIVEL_ANOSR', 'SEXO_CATEGORIA', 'EDAD_RANGO_CATEGORIA',
#        'ALFABETA_CATEGORIA', 'EDUCACION_NIVEL_EDUCATIVO_CATEGORIA', 'AÑO',
#        'PK_DEPARTAMENTO', 'DEPARTAMENTO_NOMBRE', 'FK_REGION', 'PK_MUNICIPIO',
#        'PK_MUNICIPIO_SIN_DEPARTAMENTO', 'NOMBRE_MUNICIPIO', 'LONGITUD',
#        'LACTITUD', 'FK_DEPARTAMENTO'],
#       dtype='object')

# %%
df_final = df_final.drop(columns=['U_DPTO'])
df_final = df_final.drop(columns=['U_MPIO'])
df_final = df_final.drop(columns=['P_SEXO'])
df_final = df_final.drop(columns=['P_EDADR'])
df_final = df_final.drop(columns=['P_ALFABETA'])
df_final = df_final.drop(columns=['P_NIVEL_ANOSR'])
df_final = df_final.drop(columns=['PK_DEPARTAMENTO'])
df_final = df_final.drop(columns=['FK_REGION'])
df_final = df_final.drop(columns=['PK_MUNICIPIO'])
df_final = df_final.drop(columns=['PK_MUNICIPIO_SIN_DEPARTAMENTO'])
df_final = df_final.drop(columns=['LONGITUD'])
df_final = df_final.drop(columns=['LACTITUD'])
df_final = df_final.drop(columns=['FK_DEPARTAMENTO'])

# %%
df_final.columns
# Out:
# Index(['COD_ENCUESTAS', 'SEXO_CATEGORIA', 'EDAD_RANGO_CATEGORIA',
#        'ALFABETA_CATEGORIA', 'EDUCACION_NIVEL_EDUCATIVO_CATEGORIA', 'AÑO',
#        'DEPARTAMENTO_NOMBRE', 'NOMBRE_MUNICIPIO'],
#       dtype='object')

# %%
df_final.isnull().sum()
# Out:
# COD_ENCUESTAS                          0
# SEXO_CATEGORIA                         0
# EDAD_RANGO_CATEGORIA                   0
# ALFABETA_CATEGORIA                     0
# EDUCACION_NIVEL_EDUCATIVO_CATEGORIA    0
# AÑO                                    0
# DEPARTAMENTO_NOMBRE                    0
# NOMBRE_MUNICIPIO                       0
# dtype: int64

# %% [markdown]
# ### **4. Análisis de distribución y estadístico**

# %%
for i in df_final.columns:
  print(df_final[i].describe())
  print('\n')
# Out:
# count    2.792877e+06
# mean     6.526222e+07
# std      2.130305e+08
# min      1.747500e+04
# 25%      4.801925e+06
# 50%      1.051097e+07
# 75%      1.556594e+07
# max      9.500034e+08
# Name: COD_ENCUESTAS, dtype: float64
#
#
# count     2792877
# unique          2
# top       2 Mujer
# freq      1413019
# Name: SEXO_CATEGORIA, dtype: object
#
#
# count               2792877
# unique                   21
# top       5 de 20 A 24 Años
# freq                 245838
# Name: EDAD_RANGO_CATEGORIA, dtype: object
#
#
# count     2792877
# unique          3
# top          1 SI
# freq      2470058
# Name: ALFABETA_CATEGORIA, dtype: object
#
#
# count               2792877
# unique                   10
# top       2 Básica primaria
# freq                 784723
# Name: EDUCACION_NIVEL_EDUCATIVO_CATEGORIA, dtype: object
#
#
# count    2792877.0
# mean        2018.0
# std            0.0
# min         2018.0
# 25%         2018.0
# 50%         2018.0
# 75%         2018.0
# max         2018.0
# Name: AÑO, dtype: float64
#
#
# count          2792877
# unique               1
# top       Cundinamarca
# freq           2792877
# Name: DEPARTAMENTO_NOMBRE, dtype: object
#
#
# count     2792877
# unique        116
# top        SOACHA
# freq       645205
# Name: NOMBRE_MUNICIPIO, dtype: object

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2792877 entries, 0 to 2792876
# Data columns (total 8 columns):
#  #   Column                               Dtype
# ---  ------                               -----
#  0   COD_ENCUESTAS                        int64
#  1   SEXO_CATEGORIA                       category
#  2   EDAD_RANGO_CATEGORIA                 category
#  3   ALFABETA_CATEGORIA                   category
#  4   EDUCACION_NIVEL_EDUCATIVO_CATEGORIA  category
#  5   AÑO                                  int64
#  6   DEPARTAMENTO_NOMBRE                  object
#  7   NOMBRE_MUNICIPIO                     object
# dtypes: category(4), int64(2), object(2)
# memory usage: 95.9+ MB

# %% [markdown]
# #### **4.1 Distribución de los Datos**

# %% [markdown]
# ### **5 EXPORTAR**

# %%
# Se crea una copia del dataframe organizado
df_final.to_csv('CensoPersonas2018_CategoriaCun.csv', index=False)
